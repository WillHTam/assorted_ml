# %% [markdown]
# # BTC Analysis - Statistical & ML

# %%
# %matplotlib inline
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sb
sb.set_style('darkgrid')
# Out:
# C:\Users\William\Anaconda3\envs\tf-gpu\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# # Statistical Analysis

# %%
coinbase = pd.read_csv('coindesk-bpi-USD-close_data-2010-07-18_2018-01-31.csv')

# %%
coinbase.head()
# Out:
#                   Date  Close Price
# 0  2010-07-18 00:00:00         0.09
# 1  2010-07-19 00:00:00         0.08
# 2  2010-07-20 00:00:00         0.07
# 3  2010-07-21 00:00:00         0.08
# 4  2010-07-22 00:00:00         0.05

# %%
coinbase['Date'] = coinbase['Date'].convert_objects(convert_dates='coerce')  
coinbase = coinbase.sort_index(by='Date')  
coinbase = coinbase.set_index('Date')
# Out:
# C:\Users\William\Anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
# C:\Users\William\Anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)

# %%
coinbase['Close Price'].plot(figsize=(12,10))

# %%
coinbase['First Difference'] = coinbase['Close Price'] - coinbase['Close Price'].shift()
coinbase['First Difference'].plot(figsize=(12,10))

# %% [markdown]
# Apply log transformation to refine changes

# %%
coinbase['Natural Log'] = coinbase['Close Price'].apply(lambda x: np.log(x))
coinbase['Natural Log'].plot(figsize=(12,10))

# %%
coinbase['Original Variance'] = pd.rolling_var(coinbase['Close Price'], 30, min_periods=None, freq=None, center=True)  
coinbase['Log Variance'] = pd.rolling_var(coinbase['Natural Log'], 30, min_periods=None, freq=None, center=True)
# Out:
# C:\Users\William\Anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pd.rolling_var is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=30,center=True).var()
#   """Entry point for launching an IPython kernel.
# C:\Users\William\Anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pd.rolling_var is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=30,center=True).var()

# %%
fig, ax = plt.subplots(2, 1, figsize=(12, 10))  
coinbase['Original Variance'].plot(ax=ax[0], title='Original Variance')  
coinbase['Log Variance'].plot(ax=ax[1], title='Log Variance')  
fig.tight_layout()

# %% [markdown]
# Above shows that changes are much easier to see despite their magnitude
#
# Get stationary data of logged data

# %%
coinbase['Logged First Difference'] = coinbase['Natural Log'] - coinbase['Natural Log'].shift()
coinbase['Logged First Difference'].plot(figsize=(12,10))

# %% [markdown]
# Data is now stationary

# %% [markdown]
# Create time lag variables

# %%
# Daily Lag
coinbase['Lag 1'] = coinbase['Logged First Difference'].shift()
# Weekly Lag
coinbase['Lag 5'] = coinbase['Logged First Difference'].shift(5)

# %% [markdown]
# Joint plots with lag variables vs logged first difference

# %%
sb.jointplot('Logged First Difference', 'Lag 1', coinbase, kind='reg', size=11)

# %%
sb.jointplot('Logged First Difference', 'Lag 5', coinbase, kind='reg', size=11)

# %% [markdown]
# Being zero-centered and a normal-ish distribution, not much correlation between daily or weekly prices to the current price
#
# Run acf/pacf to do this automatically

# %%
coinbase = coinbase.drop('NaT')

# %%
from statsmodels.tsa.stattools import acf
from statsmodels.tsa.stattools import pacf

# %%
lag_correlations = acf(coinbase['Logged First Difference'].iloc[1:])  
lag_partial_correlations = pacf(coinbase['Logged First Difference'].iloc[1:])

# %%
fig, ax = plt.subplots(figsize=(12,10))  
ax.plot(lag_correlations, marker='o', linestyle='--')

# %% [markdown]
# Results show that past history doesn't help much to predict current prices

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomposition = seasonal_decompose(coinbase['Natural Log'], model='additive', freq=30)

# %%
fig = plt.figure()  
fig = decomposition.plot()

# %% [markdown]
# No clear cycle in prices

# %%
model = sm.tsa.ARIMA(coinbase['Natural Log'].iloc[1:], order=(1, 0, 0))  
results = model.fit(disp=-1)  
coinbase['Forecast'] = results.fittedvalues  
coinbase[['Natural Log', 'Forecast']].plot(figsize=(12, 10))
# Out:
# C:\Users\William\Anaconda3\envs\tf-gpu\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# C:\Users\William\Anaconda3\envs\tf-gpu\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# C:\Users\William\Anaconda3\envs\tf-gpu\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):

# %% [markdown]
# So an ARIMA model run with an undifferenced model is so accurate it almost overlaps
#
# What about applying an 'I' term? Namely that of a (1,1,0) ARIMA model.
# ie. differenced-first-order autoregressive model

# %%
model = sm.tsa.ARIMA(coinbase['Natural Log'].iloc[1:], order=(1, 1, 0))  
results = model.fit(disp=-1)  
coinbase['Forecast'] = results.fittedvalues  
coinbase[['Logged First Difference', 'Forecast']].plot(figsize=(12, 10))
# Out:
# C:\Users\William\Anaconda3\envs\tf-gpu\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# C:\Users\William\Anaconda3\envs\tf-gpu\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# C:\Users\William\Anaconda3\envs\tf-gpu\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):

# %% [markdown]
# If we zoom in, poor predictions that barely move according to real changes

# %%
coinbase[['Logged First Difference', 'Forecast']].iloc[1200:1600, :].plot(figsize=(12, 10))

# %% [markdown]
# Applying statistical / pure time series methods aren't very effective.
#
# So let's try an LSTM

# %%
import datetime
import time

# %% [markdown]
# # Machine Learning Analysis

# %%
bdata = pd.read_html("https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20150101&end="+time.strftime("%Y%m%d"))[0]

# %% [markdown]
# Data that starts from the beginning of 2015 to the current date

# %%
bdata = bdata.assign(Date=pd.to_datetime(bdata['Date']))
bdata['Volume'] = bdata['Volume'].astype('int64')

# %% [markdown]
# Let's add: <br/>
#     1) Close off High: The gap between the close and high.  <br/>
#         -1 means that the close was equal to the low, 1 means close to the high <br/>
#     2) Volatility<br/>

# %%
kwargs = {
            'Close Off High': lambda x: 2*(x['High'] - x['Close'])/(x['High'] - x['Low'])-1,
             'Volatility': lambda x: (x['High'] - x['Low'])/(x['Open'])
         }

# %%
bdata = bdata.assign(**kwargs)
bdata.head()
# Out:
#         Date      Open      High      Low     Close       Volume  \
# 0 2018-02-04   9175.70   9334.87  8031.22   8277.01   7073550000
# 1 2018-02-03   8852.12   9430.75  8251.63   9174.91   7263790000
# 2 2018-02-02   9142.28   9142.28  7796.49   8830.75  12726900000
# 3 2018-02-01  10237.30  10288.80  8812.28   9170.54   9959400000
# 4 2018-01-31  10108.20  10381.60  9777.42  10221.10   8041160000
#
#      Market Cap  Close Off High  Volatility
# 0  154553000000        0.622920    0.142076
# 1  149085000000       -0.566049    0.133202
# 2  153953000000       -0.537030    0.147205
# 3  172372000000        0.514724    0.144229
# 4  170183000000       -0.468701    0.059771

# %%
# Get only relevant columns
mdata = bdata[['Date']+['Close']+['Volume']+['Close Off High']+['Volatility']]
mdata = mdata.sort_values(by='Date')
mdata.head()
# Out:
#            Date   Close    Volume  Close Off High  Volatility
# 1130 2015-01-01  314.25   8036550        0.922360    0.020097
# 1129 2015-01-02  315.03   7860650       -0.289474    0.007259
# 1128 2015-01-03  281.08  33054400        1.000000    0.108210
# 1127 2015-01-04  264.19  55629100        0.555706    0.105353
# 1126 2015-01-05  274.47  43962800       -0.416290    0.050023

# %% [markdown]
# Use all data before 1/1/2017 for training, after for test

# %%
split_date = '2017-07-01'
training_set, test_set = mdata[mdata['Date']<split_date], mdata[mdata['Date']>=split_date]
training_set = training_set.drop('Date', 1)
test_set = test_set.drop('Date', 1)

# %%
training_set.head()
# Out:
#        Close    Volume  Close Off High  Volatility
# 1130  314.25   8036550        0.922360    0.020097
# 1129  315.03   7860650       -0.289474    0.007259
# 1128  281.08  33054400        1.000000    0.108210
# 1127  264.19  55629100        0.555706    0.105353
# 1126  274.47  43962800       -0.416290    0.050023

# %%
window_len=10
norm_cols= ['Close', 'Volume']

# %%
LSTM_training_inputs = []
for i in range(len(training_set)-window_len):
    temp_set = training_set[i:(i+window_len)].copy()
    for col in norm_cols:
        temp_set.loc[:, col] = temp_set[col]/temp_set[col].iloc[0] - 1
    LSTM_training_inputs.append(temp_set)

# %% [markdown]
# Output is next price normalized to 10th previous closing price

# %%
LSTM_training_outputs = (training_set['Close'][window_len:].values/training_set['Close'][:-window_len].values)-1

# %%
LSTM_test_inputs = []
for i in range(len(test_set)-window_len):
    temp_set = test_set[i:(i+window_len)].copy()
    for col in norm_cols:
        temp_set.loc[:, col] = temp_set[col]/temp_set[col].iloc[0] - 1
    LSTM_test_inputs.append(temp_set)

# %%
LSTM_test_outputs = (test_set['Close'][window_len:].values/test_set['Close'][:-window_len].values)-1
# Epoch 32/50
# 902/902 [==============================] - 0s 363us/step - loss: 0.0309
# Epoch 33/50
# 902/902 [==============================] - 0s 314us/step - loss: 0.0309
# Epoch 34/50
# 902/902 [==============================] - 0s 332us/step - loss: 0.0306
# Epoch 35/50
# 902/902 [==============================] - 0s 360us/step - loss: 0.0312
# Epoch 36/50
# 902/902 [==============================] - 0s 399us/step - loss: 0.0302
# Epoch 37/50
# 902/902 [==============================] - 0s 349us/step - loss: 0.0305
# Epoch 38/50
# 902/902 [==============================] - 0s 364us/step - loss: 0.0300
# Epoch 39/50
# 902/902 [==============================] - 0s 322us/step - loss: 0.0297
# Epoch 40/50
# 902/902 [==============================] - 0s 293us/step - loss: 0.0292
# Epoch 41/50
# 902/902 [==============================] - 0s 380us/step - loss: 0.0292
# Epoch 42/50
# 902/902 [==============================] - 0s 358us/step - loss: 0.0290
# Epoch 43/50
# 902/902 [==============================] - 0s 348us/step - loss: 0.0301
# Epoch 44/50
# 902/902 [==============================] - 0s 349us/step - loss: 0.0291
# Epoch 45/50
# 902/902 [==============================] - 0s 389us/step - loss: 0.0295
# Epoch 46/50
# 902/902 [==============================] - 0s 288us/step - loss: 0.0288
# Epoch 47/50
# 902/902 [==============================] - 0s 359us/step - loss: 0.0288
# Epoch 48/50
# 902/902 [==============================] - 0s 371us/step - loss: 0.0281
# Epoch 49/50
# 902/902 [==============================] - 0s 367us/step - loss: 0.0279
# Epoch 50/50
# 902/902 [==============================] - 0s 364us/step - loss: 0.0286

# %%
fig, ax1 = plt.subplots(figsize=(12,10))

ax1.plot(btc_history.epoch, btc_history.history['loss'])
ax1.set_title('Training Error')

ax1.set_ylabel('Mean Absolute Error', fontsize=11)
ax1.set_xlabel('Epochs', fontsize=11)
plt.show()

# %% [markdown]
# Since the training error decreases over time, everything's good up to now

# %% [markdown]
# # Visualization of Single Timepoint Predictions

# %%
fig, ax1 = plt.subplots(figsize=(12,10))
ax1.set_xticks([datetime.date(i,j,1) for i in range(2015,2019) for j in [1,5,9]])
ax1.set_xticklabels([datetime.date(i,j,1).strftime('%b %Y')  for i in range(2015,2019) for j in [1,5,9]])
ax1.plot(mdata[mdata['Date']< split_date]['Date'][window_len:].astype(datetime.datetime),
         training_set['Close'][window_len:], label='Actual')
ax1.plot(mdata[mdata['Date']< split_date]['Date'][window_len:].astype(datetime.datetime),
         ((np.transpose(btc_model.predict(LSTM_training_inputs))+1) * training_set['Close'].values[:-window_len])[0], 
         label='Predicted')
ax1.set_title('Training Set')
ax1.set_ylabel('Bitcoin Price ($)',fontsize=12)
ax1.legend(bbox_to_anchor=(0.15, 1), loc=2, borderaxespad=0., prop={'size': 14})
ax1.annotate('MAE: %.4f'%np.mean(np.abs((np.transpose(btc_model.predict(LSTM_training_inputs))+1)-(training_set['Close'].values[window_len:])/(training_set['Close'].values[:-window_len]))), 
             xy=(0.75, 0.9),  xycoords='axes fraction',
            xytext=(0.75, 0.9), textcoords='axes fraction')
plt.show()

# %% [markdown]
# Fairly accurate here, but the model can see its errors and adjust accordingly.  That it isn't more accurate is the surprising part. Perhaps an error on my part

# %%
fig, ax1 = plt.subplots(figsize=(12,10))
ax1.set_xticks([datetime.date(2017,i+1,1) for i in range(12)])
ax1.set_xticklabels([datetime.date(2017,i+1,1).strftime('%b %d %Y')  for i in range(12)])
ax1.plot(mdata[mdata['Date']>= split_date]['Date'][window_len:].astype(datetime.datetime),
         test_set['Close'][window_len:], label='Actual')
ax1.plot(mdata[mdata['Date']>= split_date]['Date'][window_len:].astype(datetime.datetime),
         ((np.transpose(btc_model.predict(LSTM_test_inputs))+1) * test_set['Close'].values[:-window_len])[0], 
         label='Predicted')
ax1.annotate('MAE: %.4f'%np.mean(np.abs((np.transpose(btc_model.predict(LSTM_test_inputs))+1)-(test_set['Close'].values[window_len:])/(test_set['Close'].values[:-window_len]))), 
             xy=(0.75, 0.9),  xycoords='axes fraction',
            xytext=(0.75, 0.9), textcoords='axes fraction')
ax1.set_title('Test Set',fontsize=13)
ax1.set_ylabel('Bitcoin Price ($)',fontsize=12)
ax1.legend(bbox_to_anchor=(0.1, 1), loc=2, borderaxespad=0., prop={'size': 14})
plt.show()

# %% [markdown]
# Lag on the predictions, couldn't account for the big spike in December-ish, okay performance until recently where the peaks and valleys are more severe.

# %% [markdown]
# # Predicting the Future

# %%
np.random.seed(169)
# predict price for the next 7 days from now
    # just change this var to adjust
pred_range = 7
btc_model2 = build_model(LSTM_training_inputs, output_size=pred_range, neurons = 20)
# model output is next <pred_range> prices normalized to <window_len>th previous closing price
LSTM_training_outputs2 = []
for i in range(window_len, len(training_set['Close'])-pred_range):
    LSTM_training_outputs2.append((training_set['Close'][i:i+pred_range].values/
                                  training_set['Close'].values[i-window_len])-1)
LSTM_training_outputs2 = np.array(LSTM_training_outputs2)
btc_history2 = btc_model2.fit(LSTM_training_inputs[:-pred_range], LSTM_training_outputs2, 
                            epochs=80, batch_size=128, verbose=2, shuffle=True)
# Out:
# Epoch 1/50
#  - 2s - loss: 0.1014
# Epoch 2/50
#  - 0s - loss: 0.0938
# Epoch 3/50
#  - 0s - loss: 0.0902
# Epoch 4/50
#  - 0s - loss: 0.0873
# Epoch 5/50
#  - 0s - loss: 0.0833
# Epoch 6/50
#  - 0s - loss: 0.0813
# Epoch 7/50
#  - 0s - loss: 0.0797
# Epoch 8/50
#  - 0s - loss: 0.0772
# Epoch 9/50
#  - 0s - loss: 0.0761
# Epoch 10/50
#  - 0s - loss: 0.0731
# Epoch 11/50
#  - 0s - loss: 0.0726
# Epoch 12/50
#  - 0s - loss: 0.0703
# Epoch 13/50
#  - 0s - loss: 0.0688
# Epoch 14/50
#  - 0s - loss: 0.0681
# Epoch 15/50
#  - 0s - loss: 0.0667
# Epoch 16/50
#  - 0s - loss: 0.0648
# Epoch 17/50
#  - 0s - loss: 0.0634
# Epoch 18/50
#  - 0s - loss: 0.0624
# Epoch 19/50
#  - 0s - loss: 0.0610
# Epoch 20/50
#  - 0s - loss: 0.0616
# Epoch 21/50
#  - 0s - loss: 0.0591
# Epoch 22/50
#  - 0s - loss: 0.0588
# Epoch 23/50
#  - 0s - loss: 0.0573
# Epoch 24/50
#  - 0s - loss: 0.0578
# Epoch 25/50
#  - 0s - loss: 0.0558
# Epoch 26/50
#  - 0s - loss: 0.0563
# Epoch 27/50
#  - 0s - loss: 0.0558
# Epoch 28/50
#  - 0s - loss: 0.0551
# Epoch 29/50
#  - 0s - loss: 0.0547
# Epoch 30/50
#  - 0s - loss: 0.0538
# Epoch 31/50
#  - 0s - loss: 0.0535
# Epoch 32/50
#  - 0s - loss: 0.0539
# Epoch 33/50
#  - 0s - loss: 0.0530
# Epoch 34/50
#  - 0s - loss: 0.0536
# Epoch 35/50
#  - 0s - loss: 0.0529
# Epoch 36/50
#  - 0s - loss: 0.0528
# Epoch 37/50
#  - 0s - loss: 0.0519
# Epoch 38/50
#  - 0s - loss: 0.0524
# Epoch 39/50
#  - 0s - loss: 0.0524
# Epoch 40/50
#  - 0s - loss: 0.0521
# Epoch 41/50
#  - 0s - loss: 0.0512
# Epoch 42/50
#  - 0s - loss: 0.0515
# Epoch 43/50
#  - 0s - loss: 0.0523
# Epoch 44/50
#  - 0s - loss: 0.0513
# Epoch 45/50
#  - 0s - loss: 0.0518
# Epoch 46/50
#  - 0s - loss: 0.0508
# Epoch 47/50
#  - 0s - loss: 0.0507
# Epoch 48/50
#  - 0s - loss: 0.0500
# Epoch 49/50
#  - 0s - loss: 0.0500
# Epoch 50/50
#  - 0s - loss: 0.0504

# %%
fig, ax1 = plt.subplots(figsize=(10,8))

ax1.plot(btc_history2.epoch, btc_history2.history['loss'])
ax1.set_title('Training Error')

ax1.set_ylabel('Mean Absolute Error', fontsize=11)
ax1.set_xlabel('Epochs', fontsize=11)
plt.show()

# %%
prediction = ((btc_model2.predict(LSTM_test_inputs)[:-pred_range][::pred_range]+1)*test_set['Close'].values[:-(window_len + pred_range)][::pred_range].reshape(int(np.ceil((len(LSTM_test_inputs)-pred_range)/float(pred_range))),1))

# %%
pred_colors = ["#FF69B4", "#5D6D7E", "#F4D03F","#A569BD","#45B39D", "#000000", "#FFFFFF"]
fig, ax1 = plt.subplots(figsize=(12,10))
ax1.set_xticks([datetime.date(2017,i+1,1) for i in range(12)])
ax1.set_xticklabels([datetime.date(2017,i+1,1).strftime('%b %d %Y')  for i in range(12)])
ax1.plot(mdata[mdata['Date']>= split_date]['Date'][window_len:].astype(datetime.datetime),
         test_set['Close'][window_len:], label='Actual')

for i,(pred) in enumerate(prediction):
    ax1.plot(mdata[mdata['Date']>= split_date]['Date'][window_len:].astype(datetime.datetime)[i*pred_range:i*pred_range+pred_range],
                 pred, color=pred_colors[i%5], label="Predicted")
    
ax1.set_title('Predictions for %s Days'%pred_range,fontsize=13)
ax1.set_ylabel('Bitcoin Price',fontsize=12)
plt.show()

# %% [markdown]
# Not sure why some of the earlier predictions are so flat. Maybe it's because of the big shifts later on that these smaller changes are regarded as inconsequential.
