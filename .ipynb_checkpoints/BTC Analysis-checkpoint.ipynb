# %% [markdown]
# # BTC Analysis - Statistical & ML

# %%
# %matplotlib inline
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sb
sb.set_style('darkgrid')
# Out:
# C:\Users\William\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# # Statistical Analysis

# %%
coinbase = pd.read_csv('coindesk-bpi-USD-close_data-2010-07-18_2018-01-31.csv')

# %%
coinbase.head()
# Out:
#                   Date  Close Price
# 0  2010-07-18 00:00:00         0.09
# 1  2010-07-19 00:00:00         0.08
# 2  2010-07-20 00:00:00         0.07
# 3  2010-07-21 00:00:00         0.08
# 4  2010-07-22 00:00:00         0.05

# %%
coinbase['Date'] = coinbase['Date'].convert_objects(convert_dates='coerce')  
coinbase = coinbase.sort_index(by='Date')  
coinbase = coinbase.set_index('Date')
# Out:
# C:\Users\William\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
# C:\Users\William\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: by argument to sort_index is deprecated, pls use .sort_values(by=...)

# %%
coinbase['Close Price'].plot(figsize=(12,10))

# %%
coinbase['First Difference'] = coinbase['Close Price'] - coinbase['Close Price'].shift()
coinbase['First Difference'].plot(figsize=(12,10))

# %% [markdown]
# Apply log transformation to refine changes

# %%
coinbase['Natural Log'] = coinbase['Close Price'].apply(lambda x: np.log(x))
coinbase['Natural Log'].plot(figsize=(12,10))

# %%
coinbase['Original Variance'] = pd.rolling_var(coinbase['Close Price'], 30, min_periods=None, freq=None, center=True)  
coinbase['Log Variance'] = pd.rolling_var(coinbase['Natural Log'], 30, min_periods=None, freq=None, center=True)
# Out:
# C:\Users\William\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pd.rolling_var is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=30,center=True).var()
#   """Entry point for launching an IPython kernel.
# C:\Users\William\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pd.rolling_var is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=30,center=True).var()

# %%
fig, ax = plt.subplots(2, 1, figsize=(12, 10))  
coinbase['Original Variance'].plot(ax=ax[0], title='Original Variance')  
coinbase['Log Variance'].plot(ax=ax[1], title='Log Variance')  
fig.tight_layout()

# %% [markdown]
# Above shows that changes are much easier to see despite their magnitude
#
# Get stationary data of logged data

# %%
coinbase['Logged First Difference'] = coinbase['Natural Log'] - coinbase['Natural Log'].shift()
coinbase['Logged First Difference'].plot(figsize=(12,10))

# %% [markdown]
# Data is now stationary

# %% [markdown]
# Create time lag variables

# %%
# Daily Lag
coinbase['Lag 1'] = coinbase['Logged First Difference'].shift()
# Weekly Lag
coinbase['Lag 5'] = coinbase['Logged First Difference'].shift(5)

# %% [markdown]
# Joint plots with lag variables vs logged first difference

# %%
sb.jointplot('Logged First Difference', 'Lag 1', coinbase, kind='reg', size=11)

# %%
sb.jointplot('Logged First Difference', 'Lag 5', coinbase, kind='reg', size=11)

# %% [markdown]
# Being zero-centered and a normal-ish distribution, not much correlation between daily or weekly prices to the current price
#
# Run acf/pacf to do this automatically

# %%
coinbase = coinbase.drop('NaT')

# %%
from statsmodels.tsa.stattools import acf
from statsmodels.tsa.stattools import pacf

# %%
lag_correlations = acf(coinbase['Logged First Difference'].iloc[1:])  
lag_partial_correlations = pacf(coinbase['Logged First Difference'].iloc[1:])

# %%
fig, ax = plt.subplots(figsize=(12,10))  
ax.plot(lag_correlations, marker='o', linestyle='--')

# %% [markdown]
# Results show that past history doesn't help much to predict current prices

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomposition = seasonal_decompose(coinbase['Natural Log'], model='additive', freq=30)

# %%
fig = plt.figure()  
fig = decomposition.plot()

# %% [markdown]
# No clear cycle in prices

# %%
model = sm.tsa.ARIMA(coinbase['Natural Log'].iloc[1:], order=(1, 0, 0))  
results = model.fit(disp=-1)  
coinbase['Forecast'] = results.fittedvalues  
coinbase[['Natural Log', 'Forecast']].plot(figsize=(12, 10))

# %% [markdown]
# So an ARIMA model run with an undifferenced model is so accurate it almost overlaps
#
# What about applying an 'I' term? Namely that of a (1,1,0) ARIMA model.
# ie. differenced-first-order autoregressive model

# %%
model = sm.tsa.ARIMA(coinbase['Natural Log'].iloc[1:], order=(1, 1, 0))  
results = model.fit(disp=-1)  
coinbase['Forecast'] = results.fittedvalues  
coinbase[['Logged First Difference', 'Forecast']].plot(figsize=(12, 10))

# %% [markdown]
# If we zoom in, poor predictions that barely move according to real changes

# %%
coinbase[['Logged First Difference', 'Forecast']].iloc[1200:1600, :].plot(figsize=(12, 10))

# %% [markdown]
# Applying statistical / pure time series methods aren't very effective.
#
# So let's try an LSTM

# %%
import datetime
import time

# %% [markdown]
# # Machine Learning Analysis

# %%
bdata = pd.read_html("https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20150101&end="+time.strftime("%Y%m%d"))[0]

# %% [markdown]
# Data that starts from the beginning of 2015 to the current date

# %%
bdata = bdata.assign(Date=pd.to_datetime(bdata['Date']))
bdata['Volume'] = bdata['Volume'].astype('int64')

# %% [markdown]
# Let's add: <br/>
#     1) Close off High: The gap between the close and high.  <br/>
#         -1 means that the close was equal to the low, 1 means close to the high <br/>
#     2) Volatility<br/>

# %%
kwargs = {
            'Close Off High': lambda x: 2*(x['High'] - x['Close'])/(x['High'] - x['Low'])-1,
             'Volatility': lambda x: (x['High'] - x['Low'])/(x['Open'])
         }

# %%
bdata = bdata.assign(**kwargs)
bdata.head()
# Out:
#         Date     Open      High      Low    Close      Volume    Market Cap  \
# 0 2018-03-12  9602.93   9937.50  8956.43  9205.12  6457400000  162421000000
# 1 2018-03-11  8852.78   9711.89  8607.12  9578.63  6296370000  149716000000
# 2 2018-03-10  9350.59   9531.32  8828.47  8866.00  5386320000  158119000000
# 3 2018-03-09  9414.69   9466.35  8513.03  9337.55  8704190000  159185000000
# 4 2018-03-08  9951.44  10147.40  9335.87  9395.01  7186090000  168241000000
#
#    Close Off High  Volatility
# 0        0.493023    0.102164
# 1       -0.758755    0.124794
# 2        0.893206    0.075166
# 3       -0.729786    0.101259
# 4        0.854251    0.081549

# %%
# Get only relevant columns
mdata = bdata[['Date']+['Close']+['Volume']+['Close Off High']+['Volatility']]
mdata = mdata.sort_values(by='Date')
mdata.head()
# Out:
#            Date   Close    Volume  Close Off High  Volatility
# 1166 2015-01-01  314.25   8036550        0.922360    0.020097
# 1165 2015-01-02  315.03   7860650       -0.289474    0.007259
# 1164 2015-01-03  281.08  33054400        1.000000    0.108210
# 1163 2015-01-04  264.19  55629100        0.555706    0.105353
# 1162 2015-01-05  274.47  43962800       -0.416290    0.050023

# %% [markdown]
# Use all data before 1/1/2017 for training, after for test

# %%
split_date = '2017-07-01'
training_set, test_set = mdata[mdata['Date']<split_date], mdata[mdata['Date']>=split_date]
training_set = training_set.drop('Date', 1)
test_set = test_set.drop('Date', 1)

# %%
training_set.head()
# Out:
#        Close    Volume  Close Off High  Volatility
# 1166  314.25   8036550        0.922360    0.020097
# 1165  315.03   7860650       -0.289474    0.007259
# 1164  281.08  33054400        1.000000    0.108210
# 1163  264.19  55629100        0.555706    0.105353
# 1162  274.47  43962800       -0.416290    0.050023

# %%
window_len=10
norm_cols= ['Close', 'Volume']

# %%
LSTM_training_inputs = []
for i in range(len(training_set)-window_len):
    temp_set = training_set[i:(i+window_len)].copy()
    for col in norm_cols:
        temp_set.loc[:, col] = temp_set[col]/temp_set[col].iloc[0] - 1
    LSTM_training_inputs.append(temp_set)

# %% [markdown]
# Output is next price normalized to 10th previous closing price

# %%
LSTM_training_outputs = (training_set['Close'][window_len:].values/training_set['Close'][:-window_len].values)-1

# %%
LSTM_test_inputs = []
for i in range(len(test_set)-window_len):
    temp_set = test_set[i:(i+window_len)].copy()
    for col in norm_cols:
        temp_set.loc[:, col] = temp_set[col]/temp_set[col].iloc[0] - 1
    LSTM_test_inputs.append(temp_set)

# %%
LSTM_test_outputs = (test_set['Close'][window_len:].values/test_set['Close'][:-window_len].values)-1

# %% [markdown]
# Normalized Close and Volume columns, because NNs don't like big numbers

# %%
LSTM_training_inputs[0]
# Out:
#          Close    Volume  Close Off High  Volatility
# 1166  0.000000  0.000000        0.922360    0.020097
# 1165  0.002482 -0.021888       -0.289474    0.007259
# 1164 -0.105553  3.113009        1.000000    0.108210
# 1163 -0.159300  5.922013        0.555706    0.105353
# 1162 -0.126587  4.470357       -0.416290    0.050023
# 1161 -0.089292  1.892497       -0.816835    0.054077
# 1160 -0.063357  2.094213       -0.437141    0.054775
# 1159 -0.098329  1.486453        0.804184    0.040628
# 1158 -0.075863  1.329184       -0.867675    0.037467
# 1157 -0.125537  0.899360        0.882768    0.049286

# %%
LSTM_training_inputs = [np.array(LSTM_training_input) for LSTM_training_input in LSTM_training_inputs]
LSTM_training_inputs = np.array(LSTM_training_inputs)

LSTM_test_inputs = [np.array(LSTM_test_inputs) for LSTM_test_inputs in LSTM_test_inputs]
LSTM_test_inputs = np.array(LSTM_test_inputs)

# %%
import tensorflow as tf

# %%
from keras.models import Sequential
from keras.layers import Activation, Dense
from keras.layers import LSTM
from keras.layers import Dropout
# Out:
# Using TensorFlow backend.

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/cpu:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14632160672795670861
# ]

# %%
def build_model(inputs, output_size, neurons, activ_func="linear",
                dropout=0.25, loss="mae", optimizer="adam"):
    model = Sequential()

    model.add(LSTM(neurons, input_shape=(inputs.shape[1], inputs.shape[2])))
    model.add(Dropout(dropout))
    model.add(Dense(units=output_size))
    model.add(Activation(activ_func))

    model.compile(loss=loss, optimizer=optimizer)
    return model

# %% [markdown]
# build_model makes an empty model to which an LSTM layer is added.
#
# The layer is shaped to fit inputs

# %%
np.random.seed(69)
btc_model = build_model(LSTM_training_inputs, output_size=1, neurons=20)
btc_history = btc_model.fit(LSTM_training_inputs, LSTM_training_outputs, epochs=80, batch_size=128, verbose=1, shuffle=True)
# Out:
# Epoch 1/80
# 902/902 [==============================] - 1s 953us/step - loss: 0.1702
# Epoch 2/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.1429
# Epoch 3/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.1233
# Epoch 4/80
# 902/902 [==============================] - 0s 87us/step - loss: 0.1142
# Epoch 5/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0981
# Epoch 6/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0891
# Epoch 7/80
# 902/902 [==============================] - ETA: 0s - loss: 0.075 - 0s 69us/step - loss: 0.0835
# Epoch 8/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0746
# Epoch 9/80
# 902/902 [==============================] - 0s 52us/step - loss: 0.0727
# Epoch 10/80
# 902/902 [==============================] - 0s 87us/step - loss: 0.0688
# Epoch 11/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0636
# Epoch 12/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0642
# Epoch 13/80
# 902/902 [==============================] - 0s 87us/step - loss: 0.0589
# Epoch 14/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0571
# Epoch 15/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0559
# Epoch 16/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0549
# Epoch 17/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0531
# Epoch 18/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0520
# Epoch 19/80
# 902/902 [==============================] - 0s 52us/step - loss: 0.0480
# Epoch 20/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0477
# Epoch 21/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0472
# Epoch 22/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0454
# Epoch 23/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0438
# Epoch 24/80
# 902/902 [==============================] - 0s 87us/step - loss: 0.0427
# Epoch 25/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0435
# Epoch 26/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0433
# Epoch 27/80
# 902/902 [==============================] - 0s 87us/step - loss: 0.0404
# Epoch 28/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0396
# Epoch 29/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0396
# Epoch 30/80
# 902/902 [==============================] - 0s 87us/step - loss: 0.0394
# Epoch 31/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0388
# Epoch 32/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0389
# Epoch 33/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0363
# Epoch 34/80
# 902/902 [==============================] - 0s 87us/step - loss: 0.0382
# Epoch 35/80
# 902/902 [==============================] - 0s 87us/step - loss: 0.0378
# Epoch 36/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0361
# Epoch 37/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0358
# Epoch 38/80
# 902/902 [==============================] - 0s 87us/step - loss: 0.0358
# Epoch 39/80
# 902/902 [==============================] - 0s 87us/step - loss: 0.0357
# Epoch 40/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0359
# Epoch 41/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0341
# Epoch 42/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0356
# Epoch 43/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0349
# Epoch 44/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0349
# Epoch 45/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0334
# Epoch 46/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0344
# Epoch 47/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0339
# Epoch 48/80
# 902/902 [==============================] - 0s 52us/step - loss: 0.0328
# Epoch 49/80
# 902/902 [==============================] - 0s 52us/step - loss: 0.0329
# Epoch 50/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0335
# Epoch 51/80
# 902/902 [==============================] - 0s 52us/step - loss: 0.0327
# Epoch 52/80
# 902/902 [==============================] - 0s 52us/step - loss: 0.0322
# Epoch 53/80
# 902/902 [==============================] - 0s 35us/step - loss: 0.0327
# Epoch 54/80
# 902/902 [==============================] - 0s 52us/step - loss: 0.0332
# Epoch 55/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0317
# Epoch 56/80
# 902/902 [==============================] - 0s 52us/step - loss: 0.0325
# Epoch 57/80
# 902/902 [==============================] - 0s 52us/step - loss: 0.0316
# Epoch 58/80
# 902/902 [==============================] - 0s 52us/step - loss: 0.0319
# Epoch 59/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0318
# Epoch 60/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0309
# Epoch 61/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0317
# Epoch 62/80
# 902/902 [==============================] - 0s 87us/step - loss: 0.0313
# Epoch 63/80
# 902/902 [==============================] - 0s 87us/step - loss: 0.0320
# Epoch 64/80
# 902/902 [==============================] - 0s 87us/step - loss: 0.0306
# Epoch 65/80
# 902/902 [==============================] - 0s 87us/step - loss: 0.0314
# Epoch 66/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0309
# Epoch 67/80
# 902/902 [==============================] - 0s 52us/step - loss: 0.0315
# Epoch 68/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0306
# Epoch 69/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0315
# Epoch 70/80
# 902/902 [==============================] - 0s 52us/step - loss: 0.0306
# Epoch 71/80
# 902/902 [==============================] - 0s 52us/step - loss: 0.0309
# Epoch 72/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0297
# Epoch 73/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0299
# Epoch 74/80
# 902/902 [==============================] - 0s 52us/step - loss: 0.0294
# Epoch 75/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0283
# Epoch 76/80
# 902/902 [==============================] - 0s 52us/step - loss: 0.0304
# Epoch 77/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0305
# Epoch 78/80
# 902/902 [==============================] - 0s 69us/step - loss: 0.0296
# Epoch 79/80
# 902/902 [==============================] - 0s 104us/step - loss: 0.0300
# Epoch 80/80
# 902/902 [==============================] - 0s 87us/step - loss: 0.0296

# %%
fig, ax1 = plt.subplots(figsize=(12,10))

ax1.plot(btc_history.epoch, btc_history.history['loss'])
ax1.set_title('Training Error')

ax1.set_ylabel('Mean Absolute Error', fontsize=11)
ax1.set_xlabel('Epochs', fontsize=11)
plt.show()

# %% [markdown]
# Since the training error decreases over time, everything's good up to now

# %% [markdown]
# # Visualization of Single Timepoint Predictions

# %%
fig, ax1 = plt.subplots(figsize=(12,10))
ax1.set_xticks([datetime.date(i,j,1) for i in range(2015,2019) for j in [1,5,9]])
ax1.set_xticklabels([datetime.date(i,j,1).strftime('%b %Y')  for i in range(2015,2019) for j in [1,5,9]])
ax1.plot(mdata[mdata['Date']< split_date]['Date'][window_len:].astype(datetime.datetime),
         training_set['Close'][window_len:], label='Actual')
ax1.plot(mdata[mdata['Date']< split_date]['Date'][window_len:].astype(datetime.datetime),
         ((np.transpose(btc_model.predict(LSTM_training_inputs))+1) * training_set['Close'].values[:-window_len])[0], 
         label='Predicted')
ax1.set_title('Training Set')
ax1.set_ylabel('Bitcoin Price ($)',fontsize=12)
ax1.legend(bbox_to_anchor=(0.15, 1), loc=2, borderaxespad=0., prop={'size': 14})
ax1.annotate('MAE: %.4f'%np.mean(np.abs((np.transpose(btc_model.predict(LSTM_training_inputs))+1)-(training_set['Close'].values[window_len:])/(training_set['Close'].values[:-window_len]))), 
             xy=(0.75, 0.9),  xycoords='axes fraction',
            xytext=(0.75, 0.9), textcoords='axes fraction')
plt.show()

# %% [markdown]
# Fairly accurate here, but the model can see its errors and adjust accordingly.  That it isn't more accurate is the surprising part. Perhaps an error on my part

# %%
fig, ax1 = plt.subplots(figsize=(12,10))
ax1.set_xticks([datetime.date(2017,i+1,1) for i in range(12)])
ax1.set_xticklabels([datetime.date(2017,i+1,1).strftime('%b %d %Y')  for i in range(12)])
ax1.plot(mdata[mdata['Date']>= split_date]['Date'][window_len:].astype(datetime.datetime),
         test_set['Close'][window_len:], label='Actual')
ax1.plot(mdata[mdata['Date']>= split_date]['Date'][window_len:].astype(datetime.datetime),
         ((np.transpose(btc_model.predict(LSTM_test_inputs))+1) * test_set['Close'].values[:-window_len])[0], 
         label='Predicted')
ax1.annotate('MAE: %.4f'%np.mean(np.abs((np.transpose(btc_model.predict(LSTM_test_inputs))+1)-(test_set['Close'].values[window_len:])/(test_set['Close'].values[:-window_len]))), 
             xy=(0.75, 0.9),  xycoords='axes fraction',
            xytext=(0.75, 0.9), textcoords='axes fraction')
ax1.set_title('Test Set',fontsize=13)
ax1.set_ylabel('Bitcoin Price ($)',fontsize=12)
ax1.legend(bbox_to_anchor=(0.1, 1), loc=2, borderaxespad=0., prop={'size': 14})
plt.show()

# %% [markdown]
# Lag on the predictions, couldn't account for the big spike in December-ish, okay performance until recently where the peaks and valleys are more severe.

# %% [markdown]
# # Predicting the Future

# %%
np.random.seed(169)
# predict price for the next 7 days from now
    # just change this var to adjust
pred_range = 7
btc_model2 = build_model(LSTM_training_inputs, output_size=pred_range, neurons = 20)
# model output is next <pred_range> prices normalized to <window_len>th previous closing price
LSTM_training_outputs2 = []
for i in range(window_len, len(training_set['Close'])-pred_range):
    LSTM_training_outputs2.append((training_set['Close'][i:i+pred_range].values/
                                  training_set['Close'].values[i-window_len])-1)
LSTM_training_outputs2 = np.array(LSTM_training_outputs2)
btc_history2 = btc_model2.fit(LSTM_training_inputs[:-pred_range], LSTM_training_outputs2, 
                            epochs=80, batch_size=128, verbose=1, shuffle=True)
# Out:
# Epoch 1/80
# 895/895 [==============================] - 1s 1ms/step - loss: 0.1009
# Epoch 2/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0933
# Epoch 3/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0898
# Epoch 4/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0870
# Epoch 5/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0831
# Epoch 6/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0811
# Epoch 7/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0795
# Epoch 8/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0771
# Epoch 9/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0760
# Epoch 10/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0730
# Epoch 11/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0725
# Epoch 12/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0702
# Epoch 13/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0688
# Epoch 14/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0680
# Epoch 15/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0666
# Epoch 16/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0648
# Epoch 17/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0633
# Epoch 18/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0623
# Epoch 19/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0610
# Epoch 20/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0616
# Epoch 21/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0591
# Epoch 22/80
# 895/895 [==============================] - 0s 35us/step - loss: 0.0588
# Epoch 23/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0572
# Epoch 24/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0577
# Epoch 25/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0558
# Epoch 26/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0562
# Epoch 27/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0558
# Epoch 28/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0551
# Epoch 29/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0547
# Epoch 30/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0538
# Epoch 31/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0535
# Epoch 32/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0539
# Epoch 33/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0530
# Epoch 34/80
# 895/895 [==============================] - 0s 87us/step - loss: 0.0536
# Epoch 35/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0529
# Epoch 36/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0528
# Epoch 37/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0519
# Epoch 38/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0524
# Epoch 39/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0524
# Epoch 40/80
# 895/895 [==============================] - ETA: 0s - loss: 0.051 - 0s 70us/step - loss: 0.0521
# Epoch 41/80
# 895/895 [==============================] - 0s 87us/step - loss: 0.0512
# Epoch 42/80
# 895/895 [==============================] - 0s 105us/step - loss: 0.0514
# Epoch 43/80
# 895/895 [==============================] - 0s 122us/step - loss: 0.0523
# Epoch 44/80
# 895/895 [==============================] - ETA: 0s - loss: 0.050 - 0s 105us/step - loss: 0.0513
# Epoch 45/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0518
# Epoch 46/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0508
# Epoch 47/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0507
# Epoch 48/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0500
# Epoch 49/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0500
# Epoch 50/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0504
# Epoch 51/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0508
# Epoch 52/80
# 895/895 [==============================] - 0s 87us/step - loss: 0.0493
# Epoch 53/80
# 895/895 [==============================] - 0s 87us/step - loss: 0.0500
# Epoch 54/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0492
# Epoch 55/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0500
# Epoch 56/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0498
# Epoch 57/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0498
# Epoch 58/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0490
# Epoch 59/80
# 895/895 [==============================] - 0s 87us/step - loss: 0.0491
# Epoch 60/80
# 895/895 [==============================] - 0s 87us/step - loss: 0.0495
# Epoch 61/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0493
# Epoch 62/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0488
# Epoch 63/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0489
# Epoch 64/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0487
# Epoch 65/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0483
# Epoch 66/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0486
# Epoch 67/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0486
# Epoch 68/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0488
# Epoch 69/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0477
# Epoch 70/80
# 895/895 [==============================] - 0s 87us/step - loss: 0.0482
# Epoch 71/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0480
# Epoch 72/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0472
# Epoch 73/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0470
# Epoch 74/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0476
# Epoch 75/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0481
# Epoch 76/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0484
# Epoch 77/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0483
# Epoch 78/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0477
# Epoch 79/80
# 895/895 [==============================] - 0s 52us/step - loss: 0.0475
# Epoch 80/80
# 895/895 [==============================] - 0s 70us/step - loss: 0.0474

# %%
fig, ax1 = plt.subplots(figsize=(10,8))

ax1.plot(btc_history2.epoch, btc_history2.history['loss'])
ax1.set_title('Training Error')

ax1.set_ylabel('Mean Absolute Error', fontsize=11)
ax1.set_xlabel('Epochs', fontsize=11)
plt.show()

# %%
prediction = ((btc_model2.predict(LSTM_test_inputs)[:-pred_range][::pred_range]+1)*test_set['Close'].values[:-(window_len + pred_range)][::pred_range].reshape(int(np.ceil((len(LSTM_test_inputs)-pred_range)/float(pred_range))),1))

# %%
pred_colors = ["#FF69B4", "#5D6D7E", "#F4D03F","#A569BD","#45B39D", "#000000", "#FFFFFF"]
fig, ax1 = plt.subplots(figsize=(12,10))
ax1.set_xticks([datetime.date(2017,i+1,1) for i in range(12)])
ax1.set_xticklabels([datetime.date(2017,i+1,1).strftime('%b %d %Y')  for i in range(12)])
ax1.plot(mdata[mdata['Date']>= split_date]['Date'][window_len:].astype(datetime.datetime),
         test_set['Close'][window_len:], label='Actual')

for i,(pred) in enumerate(prediction):
    ax1.plot(mdata[mdata['Date']>= split_date]['Date'][window_len:].astype(datetime.datetime)[i*pred_range:i*pred_range+pred_range],
                 pred, color=pred_colors[i%5], label="Predicted")
    
ax1.set_title('Predictions for %s Days'%pred_range,fontsize=13)
ax1.set_ylabel('Bitcoin Price',fontsize=12)
plt.show()

# %% [markdown]
# Not sure why some of the earlier predictions are so flat. Maybe it's because of the big shifts later on that these smaller changes are regarded as inconsequential.

# %% [markdown]
# ## Adding Exponential Moving Average

# %%
bdata = pd.read_html("https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20150101&end="+time.strftime("%Y%m%d"))[0]

# %%
bdata.head()
# Out:
#            Date     Open      High      Low    Close      Volume    Market Cap
# 0  Mar 12, 2018  9602.93   9937.50  8956.43  9205.12  6457400000  162421000000
# 1  Mar 11, 2018  8852.78   9711.89  8607.12  9578.63  6296370000  149716000000
# 2  Mar 10, 2018  9350.59   9531.32  8828.47  8866.00  5386320000  158119000000
# 3  Mar 09, 2018  9414.69   9466.35  8513.03  9337.55  8704190000  159185000000
# 4  Mar 08, 2018  9951.44  10147.40  9335.87  9395.01  7186090000  168241000000

# %%
# 10 Day Exponential Moving Average

# Calculate Multiplier
multip = (2 / (10 + 1) )

#EMA: {Close - EMA(previous day)} x multiplier + EMA(previous day)
emas = []
def calc_ema( closeseries ):
    # The starting value is the SMA
    sma = sum( bdata['Close'][:4] ) / 4
    for _ in range(4):
        emas.append(sma)
    previous = sma
    for i in closeseries[4:]:
        result = ( ( i - previous ) * multip ) + previous
        previous = result
        emas.append(result)

# %%
kwargs = {
            'Close Off High': lambda x: 2*(x['High'] - x['Close'])/(x['High'] - x['Low'])-1,
             'Volatility': lambda x: (x['High'] - x['Low'])/(x['Open'])
         }

# %%
bdata = bdata.assign(**kwargs)
calc_ema( bdata['Close'] )
bdata['EMATen'] = emas
bdata.head()
# Out:
#            Date     Open      High      Low    Close      Volume  \
# 0  Mar 12, 2018  9602.93   9937.50  8956.43  9205.12  6457400000
# 1  Mar 11, 2018  8852.78   9711.89  8607.12  9578.63  6296370000
# 2  Mar 10, 2018  9350.59   9531.32  8828.47  8866.00  5386320000
# 3  Mar 09, 2018  9414.69   9466.35  8513.03  9337.55  8704190000
# 4  Mar 08, 2018  9951.44  10147.40  9335.87  9395.01  7186090000
#
#      Market Cap  Close Off High  Volatility       EMATen
# 0  162421000000        0.493023    0.102164  9246.825000
# 1  149716000000       -0.758755    0.124794  9246.825000
# 2  158119000000        0.893206    0.075166  9246.825000
# 3  159185000000       -0.729786    0.101259  9246.825000
# 4  168241000000        0.854251    0.081549  9273.767727

# %%
mdata = bdata[['Date']+['Close']+['Volume']+['Close Off High']+['Volatility']+['Market Cap']+['EMATen']]
mdata = mdata.sort_values(by='Date')
mdata.head()
# Out:
#               Date    Close     Volume  Close Off High  Volatility  \
# 1076  Apr 01, 2015   247.27   22877200       -0.915361    0.026124
# 710   Apr 01, 2016   417.96   51235700       -0.820513    0.005615
# 345   Apr 01, 2017  1080.50  289634000       -0.267385    0.028580
# 1075  Apr 02, 2015   253.00   26272600       -0.676991    0.036586
# 709   Apr 02, 2016   420.87   45681200       -0.338798    0.008747
#
#        Market Cap       EMATen
# 1076   3420100000   248.548136
# 710    6409540000   422.091327
# 345   17413000000  1140.457904
# 1075   3461060000   248.832167
# 709    6436700000   423.009400

# %%
split_date = '2017-07-01'
training_set, test_set = mdata[mdata['Date']<split_date], mdata[mdata['Date']>=split_date]
training_set = training_set.drop('Date', 1)
test_set = test_set.drop('Date', 1)

# %%
window_len=10
norm_cols= ['Close', 'Volume']

# %%
LSTM_training_inputs = []
for i in range(len(training_set)-window_len):
    temp_set = training_set[i:(i+window_len)].copy()
    for col in norm_cols:
        temp_set.loc[:, col] = temp_set[col]/temp_set[col].iloc[0] - 1
    LSTM_training_inputs.append(temp_set)

# %%
LSTM_training_outputs = (training_set['Close'][window_len:].values/training_set['Close'][:-window_len].values)-1

# %%
LSTM_test_inputs = []
for i in range(len(test_set)-window_len):
    temp_set = test_set[i:(i+window_len)].copy()
    for col in norm_cols:
        temp_set.loc[:, col] = temp_set[col]/temp_set[col].iloc[0] - 1
    LSTM_test_inputs.append(temp_set)

# %%
LSTM_test_outputs = (test_set['Close'][window_len:].values/test_set['Close'][:-window_len].values)-1
